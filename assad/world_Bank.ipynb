# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
m = pd.read_excel(r"C:\Users\leo\Desktop\desktop\Bootcamp\project1\proj3.xls")
m.head()
x = m['Year']
y = m['Merchandise imports from low- and middle-income economies in Sub-Saharan Africa (% of total merchandise imports)']
z= m['Merchandise exports to low- and middle-income economies within region (% of total merchandise exports)']
plt.plot(x,y)
plt.plot(x,z)
